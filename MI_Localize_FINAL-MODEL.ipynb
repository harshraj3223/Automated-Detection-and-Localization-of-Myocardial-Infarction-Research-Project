# %%
# This notebook takes the train and test NumPy files from the saved location, train a model on the training data, and calculate the overall
# and class-wise accuracies of the model.

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.5.0

# %%
# checks if any GPU is present for this notebook or not-

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# essentially checks the GPU type

from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 138743383820926600, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14509932544
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7129272937398313480
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
# import all the necessary packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import itertools
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)
# %matplotlib inline

# %%
# mount the google drive to load the necessary files (in the next cell).

from google.colab import drive
drive.mount('/content/Pdrive')
# Out:
# Mounted at /content/Pdrive

# %%
# Load the train and test data from the NumPy files saved from the first notebook.

X_train = np.load('/content/Pdrive/MyDrive/Colab Notebooks/XTrain.npy')

X_test = np.load('/content/Pdrive/MyDrive/Colab Notebooks/XTest.npy')

y_train = np.load('/content/Pdrive/MyDrive/Colab Notebooks/yTrain.npy')

y_test = np.load('/content/Pdrive/MyDrive/Colab Notebooks/yTest.npy')

# %%
# Import all the necessary things for model-training.

import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dropout, Dense, Activation
from tensorflow.keras.layers import GlobalAveragePooling1D, BatchNormalization, LSTM, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.regularizers import l1, l2, l1_l2

# %%
    reg2 = l2(0.01)  # L2 regularizer

    model = Sequential()
    model.add(Conv1D(filters=128,kernel_size=1, activation="relu", input_shape = (36, 1)))
    model.add(Conv1D(filters=128,kernel_size=1, activation="relu"))
    model.add(MaxPooling1D(pool_size=1))
    model.add(Dropout(0.1))
    model.add(Conv1D(filters=128, kernel_size=1, activation="relu"))
    model.add(Conv1D(filters=128, kernel_size=1, activation="relu"))
    model.add(MaxPooling1D(pool_size=1))
    model.add(Dropout(0.1))
    model.add(Conv1D(filters=256, kernel_size=1, activation="relu"))
    model.add(Conv1D(filters=256, kernel_size=1, activation="relu"))
    model.add(MaxPooling1D(pool_size=1))
    model.add(Dropout(0.1))
    model.add(Conv1D(filters=256, kernel_size=1, activation="relu"))
    model.add(Conv1D(filters=256, kernel_size=1, activation="relu"))
    model.add(MaxPooling1D(pool_size = 1))
    model.add(Dropout(0.1))
    model.add(Bidirectional(LSTM(256, return_sequences=True)))
    model.add(Dropout(0.1))
    model.add(Bidirectional(LSTM(128, return_sequences=True)))
    model.add(Dropout(0.1))
    model.add(Bidirectional(LSTM(128, return_sequences=True)))
    model.add(Dropout(0.1))
    model.add(Flatten())
    model.add(Dense(units=256,activation="relu", kernel_regularizer = reg2, bias_regularizer = reg2))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(units=256,activation="relu", kernel_regularizer = reg2, bias_regularizer = reg2))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(units=10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 36, 128)           256
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 36, 128)           16512
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 36, 128)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 36, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 36, 128)           16512
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 36, 128)           16512
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 36, 128)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 36, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 36, 256)           33024
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 36, 256)           65792
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 36, 256)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36, 256)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 36, 256)           65792
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 36, 256)           65792
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 36, 256)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 36, 256)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 36, 512)           1050624
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 36, 512)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 36, 256)           656384
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 36, 256)           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 36, 256)           394240
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 36, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2359552
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 4,811,402
# Trainable params: 4,810,378
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
model.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

model.fit(x = X_train, y = y_train, batch_size = 128, epochs = 70)
# Out:
# Epoch 1/70
# 221/221 [==============================] - 51s 48ms/step - loss: 7.6906 - accuracy: 0.2965
# Epoch 2/70
# 221/221 [==============================] - 10s 45ms/step - loss: 5.2008 - accuracy: 0.4624
# Epoch 3/70
# 221/221 [==============================] - 10s 45ms/step - loss: 3.8872 - accuracy: 0.5591
# Epoch 4/70
# 221/221 [==============================] - 10s 45ms/step - loss: 3.0779 - accuracy: 0.6160
# Epoch 5/70
# 221/221 [==============================] - 10s 44ms/step - loss: 2.5373 - accuracy: 0.6572
# Epoch 6/70
# 221/221 [==============================] - 10s 44ms/step - loss: 2.1692 - accuracy: 0.6840
# Epoch 7/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.8909 - accuracy: 0.7090
# Epoch 8/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.6857 - accuracy: 0.7260
# Epoch 9/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.5113 - accuracy: 0.7462
# Epoch 10/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.3814 - accuracy: 0.7604
# Epoch 11/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.2670 - accuracy: 0.7776
# Epoch 12/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.1732 - accuracy: 0.7887
# Epoch 13/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.0915 - accuracy: 0.7994
# Epoch 14/70
# 221/221 [==============================] - 10s 44ms/step - loss: 1.0254 - accuracy: 0.8089
# Epoch 15/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.9595 - accuracy: 0.8211
# Epoch 16/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.9081 - accuracy: 0.8289
# Epoch 17/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.8603 - accuracy: 0.8341
# Epoch 18/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.8212 - accuracy: 0.8415
# Epoch 19/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.7728 - accuracy: 0.8515
# Epoch 20/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.7430 - accuracy: 0.8563
# Epoch 21/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.7050 - accuracy: 0.8631
# Epoch 22/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.6782 - accuracy: 0.8703
# Epoch 23/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.6446 - accuracy: 0.8759
# Epoch 24/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.6205 - accuracy: 0.8799
# Epoch 25/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.5952 - accuracy: 0.8865
# Epoch 26/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.5740 - accuracy: 0.8916
# Epoch 27/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.5451 - accuracy: 0.8987
# Epoch 28/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.5278 - accuracy: 0.9013
# Epoch 29/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.5039 - accuracy: 0.9079
# Epoch 30/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.4853 - accuracy: 0.9128
# Epoch 31/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.4719 - accuracy: 0.9178
# Epoch 32/70
# 221/221 [==============================] - 10s 45ms/step - loss: 0.4486 - accuracy: 0.9228
# Epoch 33/70
# 221/221 [==============================] - 10s 45ms/step - loss: 0.4343 - accuracy: 0.9267
# Epoch 34/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.4177 - accuracy: 0.9312
# Epoch 35/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.4015 - accuracy: 0.9367
# Epoch 36/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3928 - accuracy: 0.9386
# Epoch 37/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3675 - accuracy: 0.9476
# Epoch 38/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3666 - accuracy: 0.9447
# Epoch 39/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3577 - accuracy: 0.9480
# Epoch 40/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3422 - accuracy: 0.9540
# Epoch 41/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3238 - accuracy: 0.9592
# Epoch 42/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3192 - accuracy: 0.9594
# Epoch 43/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3120 - accuracy: 0.9622
# Epoch 44/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3111 - accuracy: 0.9615
# Epoch 45/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.3058 - accuracy: 0.9636
# Epoch 46/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2971 - accuracy: 0.9656
# Epoch 47/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2816 - accuracy: 0.9711
# Epoch 48/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2846 - accuracy: 0.9684
# Epoch 49/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2748 - accuracy: 0.9713
# Epoch 50/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2672 - accuracy: 0.9734
# Epoch 51/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2755 - accuracy: 0.9701
# Epoch 52/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2741 - accuracy: 0.9716
# Epoch 53/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2673 - accuracy: 0.9734
# Epoch 54/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2519 - accuracy: 0.9777
# Epoch 55/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2452 - accuracy: 0.9785
# Epoch 56/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2418 - accuracy: 0.9793
# Epoch 57/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2506 - accuracy: 0.9752
# Epoch 58/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2585 - accuracy: 0.9755
# Epoch 59/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2395 - accuracy: 0.9808
# Epoch 60/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2407 - accuracy: 0.9793
# Epoch 61/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2392 - accuracy: 0.9788
# Epoch 62/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2353 - accuracy: 0.9808
# Epoch 63/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2347 - accuracy: 0.9807
# Epoch 64/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2363 - accuracy: 0.9805
# Epoch 65/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2326 - accuracy: 0.9816
# Epoch 66/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2296 - accuracy: 0.9812
# Epoch 67/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2342 - accuracy: 0.9813
# Epoch 68/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2345 - accuracy: 0.9813
# Epoch 69/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2307 - accuracy: 0.9819
# Epoch 70/70
# 221/221 [==============================] - 10s 44ms/step - loss: 0.2244 - accuracy: 0.9844

# %%
score = model.evaluate(X_test, y_test, batch_size = 128)
# Out:
# 74/74 [==============================] - 3s 21ms/step - loss: 0.3553 - accuracy: 0.9533

# %%
# THE FINAL ACCURACY RESULT OF THE MODEL:

print("Accuracy: ", round(score[1]*100, 2))
# Out:
# Accuracy:  95.33

# %%
# y_pred = an array of all the predicted classes or labels.

y_pred = np.argmax(model.predict(X_test), axis = -1)

# %%
# TO FIND THE ACCURACY OF MODEL ON EACH OF THE CLASSES 

from sklearn.metrics import confusion_matrix

cmat = confusion_matrix(y_test, y_pred)    

all_acc = cmat.diagonal()/cmat.sum(axis = 1)    # all_acc is an array containing accuracies of the model on each of the classes

# %%
all_acc
# Out:
# array([1.        , 0.98491379, 0.86190715, 0.97251266, 0.86068111,
#        1.        , 0.99865772, 1.        , 0.8539719 , 1.        ])

# %%
#PRINT THE APPROXIMATE VALUES OF ACCURACY OF MODEL ON EACH OF THE CLASSES:

for i in range(len(all_acc)):
  
  if(i==0):
    temp = 'ALMI'
  elif(i==1):
    temp = 'AMI'
  elif(i==2):
    temp = 'ASMI'
  elif(i==3):
    temp = 'ILMI'
  elif(i==4):
    temp = 'IMI'
  elif(i==5):
    temp = 'IPLMI'
  elif(i==6):
    temp = 'IPMI'
  elif(i==7):
    temp = 'LMI'
  elif(i==8):
    temp = 'NORM'
  else:
    temp = 'PMI'
  
  print('Accuracy of the model on   ' + temp + ' = ', np.round(all_acc[i]*100, 2))
# Out:
# Accuracy of the model on   ALMI =  100.0
# Accuracy of the model on   AMI =  98.49
# Accuracy of the model on   ASMI =  86.19
# Accuracy of the model on   ILMI =  97.25
# Accuracy of the model on   IMI =  86.07
# Accuracy of the model on   IPLMI =  100.0
# Accuracy of the model on   IPMI =  99.87
# Accuracy of the model on   LMI =  100.0
# Accuracy of the model on   NORM =  85.4
# Accuracy of the model on   PMI =  100.0
